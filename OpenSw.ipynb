# %% [markdown]
# # 따릉이 프로젝트
# 서울 열린데이터 광장에서 제공하는 서울시 공공자전거 데이터
# 이용하여 각종 데이터 분석 및 시각화
#
# **DataSet
#
# Data1 : 서울특별시 공공자전거 대여소 정보
# 서울특별시 공공자전거 대여소(따릉이) 현황정보입니다.
# http://data.seoul.go.kr/dataList/OA-13252/F/1/datasetView.do
#
# Data2 : 서울시 공공자전거 이용현황
# 서울시에서 운영하는 공공자전거(따릉이)에 대한 기간별, 대여소별 이용(대여, 반납)현황 데이터입니다.
# http://data.seoul.go.kr/dataList/OA-14994/F/1/datasetView.do
#
# Data3 : 서울시 공공자전거 대여소별 이용정보(월별)
# 대여일시, 대여시간, 대여소번호, 대여소명, 정기권유무, 성별, 연령대, 탄소량, 이동거리, 이동시간 정보를 제공합니다.
# http://data.seoul.go.kr/dataList/OA-15248/F/1/datasetView.do

# %%
#각종 패키지 불러오기
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import seaborn as sns
font_path = './NanumGothic.ttf' # 나눔고딕폰트 사용
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False #minus 폰트깨짐 방지

plt.style.use('seaborn')
sns.set(font="NanumGothic", 
rc={"axes.unicode_minus":False}) #seaborn 한글폰트사용

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#데이터불러오기 
#cp949 인코딩 사용 한글 데이터 커버
Data1 = pd.read_csv('data/공공자전거 대여소 정보(21.01.31 기준).csv', encoding = 'cp949')
Data2 = pd.read_csv('data/대여소별 이용정보(21.7-21.12).csv', encoding = 'cp949')
Data3 = pd.read_csv('data/서울특별시 공공자전거 이용정보(월별)_21.12.csv', encoding = 'cp949')

# %%
#데이터 확인하기
Data2.head()
# Out:
#   대여소 그룹                           대여소 명  대여 일자 / 월  대여 건수
# 0    강남구                2301. 현대고등학교 건너편     202107   2545
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)     202107   1176
# 2    강남구                  2303. 논현역 7번출구     202107   1467
# 3    강남구         2304. 신영 ROYAL PALACE 앞     202107    349
# 4    강남구              2305. MCM 본사 직영점 앞     202107    341

# %%
Data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102926 entries, 0 to 102925
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   대여일자     102926 non-null  object
#  1   대여소번호    102926 non-null  int64
#  2   대여소명     102926 non-null  object
#  3   대여구분코드   102926 non-null  object
#  4   성별       90886 non-null   object
#  5   연령대코드    102926 non-null  object
#  6   이용건수     102926 non-null  int64
#  7   운동량      102926 non-null  object
#  8   탄소량      102926 non-null  object
#  9   이동거리(M)  102926 non-null  float64
#  10  이용시간(분)  102926 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 8.6+ MB

# %%
Data3.describe()
# Out:
#                대여소번호           이용건수       이동거리(M)        이용시간(분)
# count  102926.000000  102926.000000  1.029260e+05  102926.000000
# mean     2045.927715      17.748149  3.118221e+04     345.388192
# std      1479.395437      33.310255  5.534551e+04     607.036734
# min         3.000000       1.000000  0.000000e+00       0.000000
# 25%       843.000000       2.000000  3.442557e+03      42.000000
# 50%      1729.000000       6.000000  1.128417e+04     127.000000
# 75%      3121.000000      18.000000  3.417372e+04     374.000000
# max     99999.000000    1003.000000  1.233268e+06   17190.000000

# %%
Data1.head()
# Out:
#    대여소\r\n번호    보관소(대여소)명 소재지(위치)           Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0        NaN          NaN     NaN                  NaN        NaN         NaN
# 1        NaN          NaN     자치구                 상세주소         위도          경도
# 2        NaN          NaN     NaN                  NaN        NaN         NaN
# 3        NaN          NaN     NaN                  NaN        NaN         NaN
# 4      301.0  경복궁역 7번출구 앞     종로구  서울특별시 종로구 사직로 지하130  37.575794  126.971451
#
#      설치\r\n시기      설치형태 Unnamed: 8 운영\r\n방식
# 0         NaN       LCD         QR      NaN
# 1         NaN       NaN        NaN      NaN
# 2         NaN  거치\r\n대수   거치\r\n대수      NaN
# 3         NaN       NaN        NaN      NaN
# 4  2015-10-07        16        NaN      LCD

# %%
#컬럼명 변경
Data1.columns = ['대여소번호', '대여소명', '자치구', '상세주소', '위도', '경도', '설치시기', '거치대수lcd', '거치대수qr', '운영방식']

# %%
#불필요 칼럼 제거
Data1 = Data1.drop(['상세주소', '위도', '경도'], axis = 1, inplace = False)
Data1.head()
# Out:
#    대여소번호         대여소명  자치구        설치시기   거치대수lcd    거치대수qr 운영방식
# 0    NaN          NaN  NaN         NaN       LCD        QR  NaN
# 1    NaN          NaN  자치구         NaN       NaN       NaN  NaN
# 2    NaN          NaN  NaN         NaN  거치\r\n대수  거치\r\n대수  NaN
# 3    NaN          NaN  NaN         NaN       NaN       NaN  NaN
# 4  301.0  경복궁역 7번출구 앞  종로구  2015-10-07        16       NaN  LCD

# %%
#결측치 처리
Data1['거치대수lcd'] = Data1['거치대수lcd'].fillna(0)
Data1['거치대수qr'] = Data1['거치대수qr'].fillna(0)
Data1.head()
# Out:
#    대여소번호         대여소명  자치구        설치시기   거치대수lcd    거치대수qr 운영방식
# 0    NaN          NaN  NaN         NaN       LCD        QR  NaN
# 1    NaN          NaN  자치구         NaN         0         0  NaN
# 2    NaN          NaN  NaN         NaN  거치\r\n대수  거치\r\n대수  NaN
# 3    NaN          NaN  NaN         NaN         0         0  NaN
# 4  301.0  경복궁역 7번출구 앞  종로구  2015-10-07        16         0  LCD

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2161 entries, 0 to 2160
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   대여소번호    2154 non-null   float64
#  1   대여소명     2154 non-null   object
#  2   자치구      2155 non-null   object
#  3   설치시기     2152 non-null   object
#  4   거치대수lcd  2161 non-null   object
#  5   거치대수qr   2161 non-null   object
#  6   운영방식     2154 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 118.3+ KB

# %%
Data1[Data1['대여소번호'].isnull()]
# Out:
#       대여소번호 대여소명  자치구 설치시기   거치대수lcd    거치대수qr 운영방식
# 0       NaN  NaN  NaN  NaN       LCD        QR  NaN
# 1       NaN  NaN  자치구  NaN         0         0  NaN
# 2       NaN  NaN  NaN  NaN  거치\r\n대수  거치\r\n대수  NaN
# 3       NaN  NaN  NaN  NaN         0         0  NaN
# 2158    NaN  NaN  NaN  NaN         0         0  NaN
# 2159    NaN  NaN  NaN  NaN         0         0  NaN
# 2160    NaN  NaN  NaN  NaN         0         0  NaN

# %%
# 대여소번호 == NaN -> 필요없는 데이터
# 결측치 삭제
Data1 = Data1.dropna(subset=['대여소번호'])
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2154 entries, 4 to 2157
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   대여소번호    2154 non-null   float64
#  1   대여소명     2154 non-null   object
#  2   자치구      2154 non-null   object
#  3   설치시기     2152 non-null   object
#  4   거치대수lcd  2154 non-null   object
#  5   거치대수qr   2154 non-null   object
#  6   운영방식     2154 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 134.6+ KB

# %%
#대여소명 정리 (숫자 제거)
#대여소명 구성 -> 숫자+ . +대여소이름
Data3['대여소명'].str.split('.', expand = True).head() #expand 새로운 데이터 프레임 생성
Data3['대여소명_new'] = Data3['대여소명'].str.split('.', expand = True)[1]

# %%
Data3.head(10)
# Out:
#       대여일자  대여소번호             대여소명   대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0  2021-12      3             중랑센터   일일(회원)   M  AGE_008     2    31.94
# 1  2021-12      3             중랑센터       정기   M  AGE_004     3    66.29
# 2  2021-12      3             중랑센터       정기   M  AGE_005     3    57.35
# 3  2021-12      3             중랑센터       정기   M  AGE_008     1   237.99
# 4  2021-12      5         상암센터 정비실   일일(회원)   M  AGE_004    13  1214.72
# 5  2021-12    102  102. 망원역 1번출구 앞       단체   M  AGE_001     2    76.50
# 6  2021-12    102  102. 망원역 1번출구 앞       단체   M  AGE_002     3     0.00
# 7  2021-12    102  102. 망원역 1번출구 앞  일일(비회원)  \N  AGE_008     8   338.05
# 8  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  \N  AGE_001     3   187.29
# 9  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  \N  AGE_002    95  5355.55
#
#      탄소량    이동거리(M)  이용시간(분)     대여소명_new
# 0   0.25    1090.00       23         None
# 1   0.49    2130.00       22         None
# 2   0.50    2161.63       31         None
# 3   2.02    8710.00       38         None
# 4  10.45   45109.52      356         None
# 5   0.69    2972.06       19   망원역 1번출구 앞
# 6   0.00       0.00      158   망원역 1번출구 앞
# 7   3.05   13133.04      407   망원역 1번출구 앞
# 8   1.87    8061.40       57   망원역 1번출구 앞
# 9  51.80  223391.73     2960   망원역 1번출구 앞

# %%
# 성별 \N 을 None으로 바꿈
# 결측값을 'unknown'으로 대체
Data3['성별'] = np.where(Data3['성별'] =='\\N', None, Data3['성별'])
Data3['성별'] = Data3['성별'].fillna('unknown')
Data3.head(10)
# Out:
#       대여일자  대여소번호             대여소명   대여구분코드       성별    연령대코드  이용건수      운동량  \
# 0  2021-12      3             중랑센터   일일(회원)        M  AGE_008     2    31.94
# 1  2021-12      3             중랑센터       정기        M  AGE_004     3    66.29
# 2  2021-12      3             중랑센터       정기        M  AGE_005     3    57.35
# 3  2021-12      3             중랑센터       정기        M  AGE_008     1   237.99
# 4  2021-12      5         상암센터 정비실   일일(회원)        M  AGE_004    13  1214.72
# 5  2021-12    102  102. 망원역 1번출구 앞       단체        M  AGE_001     2    76.50
# 6  2021-12    102  102. 망원역 1번출구 앞       단체        M  AGE_002     3     0.00
# 7  2021-12    102  102. 망원역 1번출구 앞  일일(비회원)  unknown  AGE_008     8   338.05
# 8  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_001     3   187.29
# 9  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_002    95  5355.55
#
#      탄소량    이동거리(M)  이용시간(분)     대여소명_new
# 0   0.25    1090.00       23         None
# 1   0.49    2130.00       22         None
# 2   0.50    2161.63       31         None
# 3   2.02    8710.00       38         None
# 4  10.45   45109.52      356         None
# 5   0.69    2972.06       19   망원역 1번출구 앞
# 6   0.00       0.00      158   망원역 1번출구 앞
# 7   3.05   13133.04      407   망원역 1번출구 앞
# 8   1.87    8061.40       57   망원역 1번출구 앞
# 9  51.80  223391.73     2960   망원역 1번출구 앞

# %%
#정비센터-> 대여소해당X 대여소명 결측값
Data3[Data3['대여소명_new'].isnull()]
# Out:
#            대여일자  대여소번호      대여소명   대여구분코드       성별    연령대코드  이용건수      운동량  \
# 0       2021-12      3      중랑센터   일일(회원)        M  AGE_008     2    31.94
# 1       2021-12      3      중랑센터       정기        M  AGE_004     3    66.29
# 2       2021-12      3      중랑센터       정기        M  AGE_005     3    57.35
# 3       2021-12      3      중랑센터       정기        M  AGE_008     1   237.99
# 4       2021-12      5  상암센터 정비실   일일(회원)        M  AGE_004    13  1214.72
# 102885  2021-12   9985      천왕센터       정기        M  AGE_004     1    25.98
# 102886  2021-12   9992     사대문센터   일일(회원)        M  AGE_004    10   970.00
# 102892  2021-12   9999      상담센터       단체  unknown  AGE_003     1     0.00
# 102893  2021-12   9999      상담센터       단체        F  AGE_002     1    70.91
# 102894  2021-12   9999      상담센터       단체        F  AGE_003     1    75.03
# 102895  2021-12   9999      상담센터       단체        M  AGE_001     1    13.70
# 102896  2021-12   9999      상담센터       단체        M  AGE_008     1   337.02
# 102897  2021-12   9999      상담센터  일일(비회원)  unknown  AGE_008     3   123.55
# 102898  2021-12   9999      상담센터   일일(회원)  unknown  AGE_002     2     7.99
# 102899  2021-12   9999      상담센터   일일(회원)  unknown  AGE_003     1    38.69
# 102900  2021-12   9999      상담센터   일일(회원)  unknown  AGE_008     1     0.00
# 102901  2021-12   9999      상담센터   일일(회원)  unknown  AGE_002     2    43.97
# 102902  2021-12   9999      상담센터   일일(회원)        F  AGE_001     3   272.28
# 102903  2021-12   9999      상담센터   일일(회원)        F  AGE_002     2    84.43
# 102904  2021-12   9999      상담센터   일일(회원)        F  AGE_003     2    75.16
# 102905  2021-12   9999      상담센터   일일(회원)        M  AGE_002     7    78.50
# 102906  2021-12   9999      상담센터   일일(회원)        M  AGE_004     2    63.73
# 102907  2021-12   9999      상담센터   일일(회원)        M  AGE_008     1    19.92
# 102908  2021-12   9999      상담센터       정기  unknown  AGE_002    12   100.23
# 102909  2021-12   9999      상담센터       정기  unknown  AGE_003     3    90.17
# 102910  2021-12   9999      상담센터       정기  unknown  AGE_004     3    36.29
# 102911  2021-12   9999      상담센터       정기  unknown  AGE_008     2    40.26
# 102912  2021-12   9999      상담센터       정기  unknown  AGE_003     1    28.83
# 102913  2021-12   9999      상담센터       정기  unknown  AGE_004     1    10.55
# 102914  2021-12   9999      상담센터       정기        F  AGE_002     4    47.09
# 102915  2021-12   9999      상담센터       정기        F  AGE_003     3    16.47
# 102916  2021-12   9999      상담센터       정기        F  AGE_005     3   469.65
# 102917  2021-12   9999      상담센터       정기        M  AGE_001     2     3.13
# 102918  2021-12   9999      상담센터       정기        M  AGE_002     4    33.08
# 102919  2021-12   9999      상담센터       정기        M  AGE_003     7    31.36
# 102920  2021-12   9999      상담센터       정기        M  AGE_004     6   210.25
# 102921  2021-12   9999      상담센터       정기        M  AGE_005     2    77.06
# 102922  2021-12   9999      상담센터       정기        M  AGE_006     1     6.38
# 102923  2021-12   9999      상담센터       정기        M  AGE_008     2    82.11
#
#           탄소량   이동거리(M)  이용시간(분) 대여소명_new
# 0        0.25   1090.00       23     None
# 1        0.49   2130.00       22     None
# 2        0.50   2161.63       31     None
# 3        2.02   8710.00       38     None
# 4       10.45  45109.52      356     None
# 102885   0.19    820.00        7     None
# 102886   8.36  36021.44      310     None
# 102892   0.00      0.00       14     None
# 102893   0.88   3810.00       33     None
# 102894   0.81   3508.63       49     None
# 102895   0.13    540.67        5     None
# 102896   2.82  12158.00       57     None
# 102897   1.11   4800.00       74     None
# 102898   0.07    310.58        9     None
# 102899   0.29   1252.47        8     None
# 102900   0.00      0.00        9     None
# 102901   0.29   1237.86       12     None
# 102902   2.48  10689.28      153     None
# 102903   0.76   3280.00       57     None
# 102904   0.68   2919.82       65     None
# 102905   0.73   3126.05      179     None
# 102906   0.48   2090.00       42     None
# 102907   0.15    628.69        5     None
# 102908   0.77   3321.25       77     None
# 102909   0.76   3269.65       29     None
# 102910   0.33   1410.00       43     None
# 102911   0.52   2259.18       85     None
# 102912   0.26   1120.00        6     None
# 102913   0.10    410.00        3     None
# 102914   0.45   1973.34        5     None
# 102915   0.19    800.00       21     None
# 102916   4.94  21254.52      119     None
# 102917   0.04    161.19      121     None
# 102918   0.24   1039.58       24     None
# 102919   0.23    990.00       31     None
# 102920   1.89   8140.27      150     None
# 102921   0.64   2780.00       31     None
# 102922   0.05    230.10        2     None
# 102923   0.74   3190.00       28     None

# %%
# 대여소가 정비센터 -> 삭제
Data3 = Data3.dropna(subset=['대여소명_new'])
Data3.head(10)
# Out:
#        대여일자  대여소번호             대여소명   대여구분코드       성별    연령대코드  이용건수      운동량  \
# 5   2021-12    102  102. 망원역 1번출구 앞       단체        M  AGE_001     2    76.50
# 6   2021-12    102  102. 망원역 1번출구 앞       단체        M  AGE_002     3     0.00
# 7   2021-12    102  102. 망원역 1번출구 앞  일일(비회원)  unknown  AGE_008     8   338.05
# 8   2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_001     3   187.29
# 9   2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_002    95  5355.55
# 10  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_003    25  1116.58
# 11  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_004     5   489.01
# 12  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_008    14  1084.35
# 13  2021-12    102  102. 망원역 1번출구 앞   일일(회원)  unknown  AGE_002     4   108.51
# 14  2021-12    102  102. 망원역 1번출구 앞   일일(회원)        F  AGE_001     5   143.19
#
#       탄소량    이동거리(M)  이용시간(분)     대여소명_new
# 5    0.69    2972.06       19   망원역 1번출구 앞
# 6    0.00       0.00      158   망원역 1번출구 앞
# 7    3.05   13133.04      407   망원역 1번출구 앞
# 8    1.87    8061.40       57   망원역 1번출구 앞
# 9   51.80  223391.73     2960   망원역 1번출구 앞
# 10   8.63   37173.74      430   망원역 1번출구 앞
# 11   5.23   22563.37      203   망원역 1번출구 앞
# 12  10.06   43408.97      290   망원역 1번출구 앞
# 13   1.01    4356.99      112   망원역 1번출구 앞
# 14   1.31    5640.27      133   망원역 1번출구 앞

# %%
#Data2도 Data3와 마찬가지로 대여소명을 번호와 구분지어서 생성
Data2['대여소번호'] = Data2['대여소 명'].str.split(".", expand = True)[0]
Data2['대여소명_new'] = Data2['대여소 명'].str.split(".", expand = True)[1]

# %%
Data2.head(10)
# Out:
#   대여소 그룹                           대여소 명  대여 일자 / 월  대여 건수 대여소번호  \
# 0    강남구                2301. 현대고등학교 건너편     202107   2545  2301
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)     202107   1176  2302
# 2    강남구                  2303. 논현역 7번출구     202107   1467  2303
# 3    강남구         2304. 신영 ROYAL PALACE 앞     202107    349  2304
# 4    강남구              2305. MCM 본사 직영점 앞     202107    341  2305
# 5    강남구              2306. 압구정역 2번 출구 옆     202107   1265  2306
# 6    강남구             2307. 압구정 한양 3차 아파트     202107    383  2307
# 7    강남구                  2308. 압구정파출소 앞     202107    673  2308
# 8    강남구              2309. 청담역(우리들병원 앞)     202107    418  2309
# 9    강남구            2310. 청담동 맥도날드 옆(위치)     202107    410  2310
#
#                     대여소명_new
# 0                 현대고등학교 건너편
# 1   교보타워 버스정류장(신논현역 3번출구 후면)
# 2                   논현역 7번출구
# 3          신영 ROYAL PALACE 앞
# 4               MCM 본사 직영점 앞
# 5               압구정역 2번 출구 옆
# 6              압구정 한양 3차 아파트
# 7                   압구정파출소 앞
# 8               청담역(우리들병원 앞)
# 9             청담동 맥도날드 옆(위치)

# %%
#정비센터-> 대여소해당X 대여소명 결측값
Data2[Data2['대여소명_new'].isnull()]
# Out:
#        대여소 그룹      대여소 명  대여 일자 / 월  대여 건수      대여소번호 대여소명_new
# 2198     정비센터       상담센터     202107    138       상담센터     None
# 2199     정비센터   상암센터 정비실     202107      8   상암센터 정비실     None
# 2200     정비센터        위트콤     202107      8        위트콤     None
# 2201     정비센터       중랑센터     202107     24       중랑센터     None
# 2202     정비센터       천왕센터     202107      1       천왕센터     None
# 2203     정비센터       천호센터     202107      0       천호센터     None
# 2204     정비센터      훈련원센터     202107      3      훈련원센터     None
# 2477   그룹명 없음    대여소명 없음     202108      0    대여소명 없음     None
# 4694     정비센터     도봉정비센터     202108      7     도봉정비센터     None
# 4695     정비센터       상담센터     202108    175       상담센터     None
# 4696     정비센터   상암센터 정비실     202108      5   상암센터 정비실     None
# 4697     정비센터        위트콤     202108      7        위트콤     None
# 4698     정비센터       중랑센터     202108      9       중랑센터     None
# 4699     정비센터      훈련원센터     202108      1      훈련원센터     None
# 4971   그룹명 없음    대여소명 없음     202109      0    대여소명 없음     None
# 7194     정비센터  9990_도봉센터     202109      1  9990_도봉센터     None
# 7198     정비센터      사대문센터     202109      4      사대문센터     None
# 7199     정비센터       상담센터     202109    203       상담센터     None
# 7200     정비센터   상암센터 정비실     202109      7   상암센터 정비실     None
# 7201     정비센터       중랑센터     202109     13       중랑센터     None
# 7475   그룹명 없음    대여소명 없음     202110      0    대여소명 없음     None
# 9727     정비센터      사대문센터     202110      5      사대문센터     None
# 9728     정비센터       상담센터     202110    181       상담센터     None
# 9729     정비센터   상암센터 정비실     202110     10   상암센터 정비실     None
# 9730     정비센터       중랑센터     202110     22       중랑센터     None
# 10010  그룹명 없음    대여소명 없음     202111      0    대여소명 없음     None
# 12276    정비센터      사대문센터     202111      2      사대문센터     None
# 12277    정비센터       상담센터     202111    129       상담센터     None
# 12278    정비센터   상암센터 정비실     202111     19   상암센터 정비실     None
# 12279    정비센터        위트콤     202111      2        위트콤     None
# 12280    정비센터       중랑센터     202111      3       중랑센터     None
# 12281    정비센터       천왕센터     202111      0       천왕센터     None
# 12282    정비센터       천호센터     202111      4       천호센터     None
# 12283    정비센터      학여울센터     202111      1      학여울센터     None
# 12560  그룹명 없음    대여소명 없음     202112      0    대여소명 없음     None
# 14864    정비센터      사대문센터     202112     10      사대문센터     None
# 14865    정비센터       상담센터     202112     87       상담센터     None
# 14866    정비센터   상암센터 정비실     202112     13   상암센터 정비실     None
# 14867    정비센터       중랑센터     202112      9       중랑센터     None
# 14868    정비센터       천왕센터     202112      1       천왕센터     None

# %%
NewData2 = Data2.dropna(subset=['대여소명_new'])
